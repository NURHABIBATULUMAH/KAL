# %% [markdown]
# # PERKALIAN TITIK (DOT PRODUCT)
#
# 1. buat program untuk menghitung dot product vector (perkalian titik dari dua vector)
#
# 2. buat program untuk mengkonversi vektor menjadi vektor satuan (vektor memiliki panjang vektor 1)
